# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
drive_path = "/content/drive/MyDrive/Colab\ Notebooks/cs7643-fp-2/cs7643-fp"
work_dir = "/home/workdir/"

# !mkdir -p {work_dir}
# %cd {work_dir}
# !cp -r {drive_path} {work_dir}
# Out:
# /home/workdir
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/cs7643-fp-2/cs7643-fp': No such file or directory

# %%
work_dir = "/home/workdir/cs7643-fp/"
# %cd {work_dir}
# Out:
# /home/workdir/cs7643-fp

# %%
# !ls -a
# Out:
# .  ..

# %%
data_path = f"{work_dir}/data/"

# %cd {data_path}
# !unzip resized2014.zip
# Out:
# [Errno 2] No such file or directory: '/home/workdir/cs7643-fp//data/'
# /home/workdir/cs7643-fp
# unzip:  cannot find or open resized2014.zip, resized2014.zip.zip or resized2014.zip.ZIP.
