# %%
import numpy as np
A = np.ones((3,3))
w = np.array([0.0, 0.1, 0.2])
print ((A*w).sum())
print ((A*w).sum(axis=0))
print ((A*w).sum(axis=1))
# Out:
# 0.9000000000000001
# [0.  0.3 0.6]
# [0.3 0.3 0.3]
