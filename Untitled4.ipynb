# %%
import numpy as np

# %%
a = np.random.randint(0,high = 50,size=(10,2,3))
a = a.reshape((10,6))
print(a)
a = a.reshape((10,2,3))
print(a)
# Out:
# [[39 49 29 30 26 20]
#  [ 0 27 46 11 27 44]
#  [28 48 49 34 42 13]
#  [ 1 45 11 34  6 47]
#  [11 10 12  1 43 35]
#  [24  0 24 25 15 44]
#  [22 13 17 22  2 32]
#  [31 14 29 15 15 25]
#  [ 1 31 18 31  4 40]
#  [ 4 27 46 37 28 12]]
# [[[39 49 29]
#   [30 26 20]]
#
#  [[ 0 27 46]
#   [11 27 44]]
#
#  [[28 48 49]
#   [34 42 13]]
#
#  [[ 1 45 11]
#   [34  6 47]]
#
#  [[11 10 12]
#   [ 1 43 35]]
#
#  [[24  0 24]
#   [25 15 44]]
#
#  [[22 13 17]
#   [22  2 32]]
#
#  [[31 14 29]
#   [15 15 25]]
#
#  [[ 1 31 18]
#   [31  4 40]]
#
#  [[ 4 27 46]
#   [37 28 12]]]
